# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
trump_posts = pd.read_csv("realdonaldtrump-truthsocial-20221101-present.tsv", sep="\t", engine="python", on_bad_lines="skip")
trump_posts.head()
# Out:
#                    id         username                 date  reblog_flag  \
# 0  109267074253249728  realDonaldTrump  2022-11-01 02:13:57          1.0
# 1  109269853202681557  realDonaldTrump  2022-11-01 14:00:40          NaN
# 2  109269869277798724  realDonaldTrump  2022-11-01 14:04:46          NaN
# 3  109269872730277773  realDonaldTrump  2022-11-01 14:05:38          NaN
# 4  109269871636367797  realDonaldTrump  2022-11-01 14:05:22          NaN
#
#    quote_flag  replies_count  reblogs_count  favourites_count  \
# 0         NaN          651.0         5242.0           23119.0
# 1         NaN          862.0         5423.0           12126.0
# 2         NaN          749.0         6304.0           14987.0
# 3         NaN          137.0         2461.0           10388.0
# 4         NaN          130.0         2524.0            8963.0
#
#                                              content  \
# 0                              RT @PatriotsInControl
# 1  Here we go again! Rigged Election! https:// ju...
# 2  We really are living in a Communist Country. W...
# 3  https://www. texastribune.org/2022/10/22/do na...
# 4  https://www. rsbnetwork.com/news/venezuela- on...
#
#                                         content_html  ...  notes  \
# 0  <p>RT <span class="h-card"><a href="https://tr...  ...    NaN
# 1  <p>Here we go again! Rigged Election! <a href=...  ...    NaN
# 2  <p>We really are living in a Communist Country...  ...    NaN
# 3  <p><a href="https://www.texastribune.org/2022/...  ...    NaN
# 4  <p><a href="https://www.rsbnetwork.com/news/ve...  ...    NaN
#
#    deleted_flag  deleted_date  readability_flag sentiment_flag  index_flag  \
# 0           NaN           NaN               1.0            1.0           1
# 1           NaN           NaN               1.0            1.0           1
# 2           NaN           NaN               1.0            1.0           1
# 3           NaN           NaN               1.0            1.0           1
# 4           NaN           NaN               1.0            1.0           1
#
#   entity_flag auto_id              created             modified
# 0         1.0  525837  2022-11-01 02:14:02  2026-02-22 07:10:11
# 1         1.0  525839  2022-11-01 14:01:02  2026-02-22 07:10:11
# 2         1.0  525841  2022-11-01 14:05:01  2026-02-22 07:10:11
# 3         1.0  525843  2022-11-01 14:06:02  2026-02-22 07:10:11
# 4         1.0  525844  2022-11-01 14:06:02  2026-02-22 07:10:11
#
# [5 rows x 56 columns]

# %%
trump_posts.shape
# Out:
# (30309, 56)

# %% [markdown]
# ## Data Cleaning & Exploration - Social Media

# %%
#filters for posts just related to tariffs
tariff_posts = trump_posts[trump_posts["content"].str.contains(r"\btariffs?\b", case=False, na=False)]
tariff_posts.shape
# Out:
# (357, 56)

# %%
#convert tariff post timestamps to look at separate date and hour
tariff_posts = trump_posts[
    trump_posts["content"].str.contains("tariff", case=False, na=False)
].copy()

tariff_posts["date"] = pd.to_datetime(tariff_posts["date"])
tariff_posts["post_date"] = tariff_posts["date"].dt.date
tariff_posts["post_hour"] = tariff_posts["date"].dt.hour
#determine if post was made after market close
tariff_posts["after_close"] = tariff_posts["post_hour"] >= 16

# %%
#assign trading day
tariff_posts["event_day"] = tariff_posts["date"].dt.date
tariff_posts.loc[tariff_posts["after_close"], "event_day"] += pd.Timedelta(days=1)

# %%
#look at how many of Trump's Truth Social posts are about tariffs
labels = ["Tariff Posts", "Other Posts"]
values = [len(tariff_posts), len(trump_posts) - len(tariff_posts)]

total = sum(values)
percentages = [(v / total) * 100 for v in values]

plt.figure(figsize=(6,5))
bars = plt.bar(labels, values, color=["#1f77b4"])

for i, bar in enumerate(bars):
    plt.text(bar.get_x() + bar.get_width()/2,
             bar.get_height(),
             f"{percentages[i]:.1f}%",
             ha='center',
             va='bottom')

plt.title("Share of Trump Truth Social Posts About Tariffs")
plt.ylabel("Number of Posts")

plt.show()

# %%
#look at frequency of tariff-related posts, are there particular high months?


tariff_posts["month"] = tariff_posts["date"].dt.to_period("M")
monthly_posts = tariff_posts.groupby("month").size()

plt.figure(figsize=(12,6))
monthly_posts.plot(marker="o")

plt.title("Frequency of Tariff-Related Posts Over Time", fontsize=14)
plt.xlabel("Month")
plt.ylabel("Number of Posts")

plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Merge Financial Data

# %%
import yfinance as yf
sp500 = yf.download("^GSPC", start="2022-11-01", end = "2026-03-10")
sp500.columns = sp500.columns.droplevel(1)
sp500.head()
# Out:
# /tmp/ipykernel_37603/3258846449.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   sp500 = yf.download("^GSPC", start="2022-11-01", end = "2026-03-10")
# [*********************100%***********************]  1 of 1 completed
# Price             Close         High          Low         Open      Volume
# Date
# 2022-11-01  3856.100098  3911.790039  3843.800049  3901.790039  4481210000
# 2022-11-02  3759.689941  3894.439941  3758.679932  3852.899902  4899000000
# 2022-11-03  3719.889893  3750.590088  3698.149902  3733.250000  4625290000
# 2022-11-04  3770.550049  3796.340088  3708.840088  3766.979980  5400180000
# 2022-11-07  3806.800049  3813.949951  3764.699951  3780.709961  4341620000

# %%
#calculate the daily returns
sp500["return"] = sp500["Close"].pct_change()
sp500.head()
# Out:
# Price             Close         High          Low         Open      Volume  \
# Date
# 2022-11-01  3856.100098  3911.790039  3843.800049  3901.790039  4481210000
# 2022-11-02  3759.689941  3894.439941  3758.679932  3852.899902  4899000000
# 2022-11-03  3719.889893  3750.590088  3698.149902  3733.250000  4625290000
# 2022-11-04  3770.550049  3796.340088  3708.840088  3766.979980  5400180000
# 2022-11-07  3806.800049  3813.949951  3764.699951  3780.709961  4341620000
#
# Price         return
# Date
# 2022-11-01       NaN
# 2022-11-02 -0.025002
# 2022-11-03 -0.010586
# 2022-11-04  0.013619
# 2022-11-07  0.009614

# %%
# Estimate daily variance using the Garman–Klass estimator
sp500["variance"] = (0.5 * (np.log(sp500['High'] / sp500['Low'])**2) - (2*np.log(2) - 1) * (np.log(sp500['Close'] / sp500['Open'])**2))
sp500.head()
# Out:
# Price             Close         High          Low         Open      Volume  \
# Date
# 2022-11-01  3856.100098  3911.790039  3843.800049  3901.790039  4481210000
# 2022-11-02  3759.689941  3894.439941  3758.679932  3852.899902  4899000000
# 2022-11-03  3719.889893  3750.590088  3698.149902  3733.250000  4625290000
# 2022-11-04  3770.550049  3796.340088  3708.840088  3766.979980  5400180000
# 2022-11-07  3806.800049  3813.949951  3764.699951  3780.709961  4341620000
#
# Price         return  variance
# Date
# 2022-11-01       NaN  0.000100
# 2022-11-02 -0.025002  0.000398
# 2022-11-03 -0.010586  0.000094
# 2022-11-04  0.013619  0.000272
# 2022-11-07  0.009614  0.000066

# %%
sp500 = sp500.reset_index()
sp500["Date"] = pd.to_datetime(sp500["Date"]).dt.date
print(sp500["Date"].min(), sp500["Date"].max())
print(tariff_posts["event_day"].min(), tariff_posts["event_day"].max())
# Out:
# 2022-11-01 2026-03-09
# 2023-02-18 2026-03-06

# %%
tariff_days = tariff_posts["event_day"].unique()
sp500["tariff_day"] = sp500["Date"].isin(tariff_days)
sp500.groupby("tariff_day")["return"].mean()
# Out:
# tariff_day
# False    0.000958
# True    -0.000293
# Name: return, dtype: float64

# %%
#look at the daily s&p returns
plt.figure(figsize=(12,6))

plt.plot(sp500["Date"], sp500["return"])

plt.title("Daily S&P 500 Returns Over Time")
plt.xlabel("Date")
plt.ylabel("Daily Return")

plt.axhline(0, linestyle="--", color="black")
plt.show()

# %% [markdown]
# ## Comparisson of S&P 500 Performance on Tariff Days and Non Tariff Days

# %%
mean_returns = sp500.groupby("tariff_day")["return"].mean()
mean_returns.index = ["No Tariff Posts", "Tariff Post Days"]

plt.figure(figsize=(6,5))
mean_returns.plot(kind="bar")

plt.title("Average Market Returns Following Tariff-Related Posts")
plt.xlabel("Tariff Post Day")
plt.ylabel("Average Daily Return")

plt.xticks(rotation=0)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(sp500[sp500["tariff_day"] == True]["variance"], bins=30, alpha=0.7, label="Tariff Days", color="blue")
plt.hist(sp500[sp500["tariff_day"] == False]["variance"], bins=30, alpha=0.7, label="Non-Tariff Days", color="red")
plt.title("Distribution of Daily S&P 500 Variance")
plt.xlabel("Variance")
plt.ylabel("Frequency")
plt.legend()
plt.show()

# %%
from scipy.stats import ttest_ind

# Split into two groups
var_true = sp500.loc[sp500['tariff_day'] == True, 'variance']
var_false = sp500.loc[sp500['tariff_day'] == False, 'variance']

# Welch's t-test (recommended when variances differ)
t_stat, p_val = ttest_ind(var_true, var_false, equal_var=False, alternative = "greater")

print("t-statistic:", t_stat)
print("p-value:", p_val)
# Out:
# t-statistic: 2.1661396919133105
# p-value: 0.015896401657603858

# %%
print(sp500[sp500["tariff_day"] == True]["variance"].geomean())
print(sp500[sp500["tariff_day"] == False]["variance"].mean())
# Out:
# 0.00010208191853775828
# 4.636791539072205e-05
